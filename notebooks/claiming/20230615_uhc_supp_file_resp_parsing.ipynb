# %%
import os
import re
import sys
import time
import random
import warnings
import collections
from dateutil.relativedelta import relativedelta
from datetime import datetime
from tqdm import tqdm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns

sys.path.append('../../src')
import cb_utils

sns.set(style="darkgrid")
pd.options.display.max_columns = 500
pd.options.display.max_colwidth = None

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Script to parse supplemental file response from UHC

# %%
file_path = '/Users/bp/workspace/cb/data/00795_UHC_ASMP_DIRECT_20230608102118_RESUB1.txt'

# %% [markdown]
# ### Columns from the file we built

# %%
dx_cols = [f'DX_{i}' for i in range(40)]
columns = [
    'SEG TYPE',
    'REF #',
    'LAST NAME',
    'FIRST NAME',
    'MI',
    'DOB',
    'MEMBER ID- need either member ID or MBI',
    'Retrieval NPI (Internal Use)',
    'GENDER',
    'STATE CODE',
    'MBI-  need either member ID or MBI',
    'FDOS',
    'TDOS',
    'BILL TYPE- Institutional Only',
    'NU Indicator (Internal Use)',
    'PROV ID',
    'NPI',
    'PROV TYPE',
    'FACILITY NM- required for Institutional',
    'PROV LAST NAME- Required for Professional',
    'PROV FIRST NAME- required for Professional',
    'CMS SPECIALTY- Required for Professional',
    'TAX ID',
    'CPT- Professional and Hospital Outpatient only',
    'REV CODE - Required for Institutional',
    'SERVICE FDOS',
    'SERVICE TDOS',
    'POS- Professional only',
    'ICD INDIC',
    'RA Code- Required for Professional',
    'Chart Barcode (Internal Use)',
    'Chart Enc Key (Internal Use)',
    'Chart DX Key  (Internal Use)',
    'Contract ID (Tufts use only)',
    'Mem Street Address ',
    'Mem Address 2',
    'Mem City',
    'Mem State',
    'Mem Zip Code',
    'CLAIMID/PCN',
] + dx_cols

# %% [markdown]
# ### response

# %%
cols = [re.sub('[^0-9a-zA-Z]+', '_', c.lower()) for c in columns+['err_id', 'error']]
df = pd.read_csv(file_path, sep='|', header=None, skipfooter=1, skiprows=1, names=cols, engine='python')
df.head()
# Out:
#   seg_type             ref_ last_name first_name   mi         dob  \
# 0      DTL  493387270586524  Schlayer      Edith  NaN  03/08/1950
# 1      DTL  614232323915932      Bear     Isaiah  NaN  10/30/1995
# 2      DTL  556769413890204     Hayes     Thomas  NaN  10/25/1982
# 3      DTL  559953381752988       Ray      Betty  NaN  03/16/1937
# 4      DTL  491633387700380  Hammonds        Joe  NaN  08/10/1954
#
#    member_id_need_either_member_id_or_mbi  retrieval_npi_internal_use_ gender  \
# 0                                     NaN                          NaN      F
# 1                                     NaN                          NaN      M
# 2                                     NaN                          NaN      M
# 3                                     NaN                          NaN      F
# 4                                     NaN                          NaN      M
#
#    state_code mbi_need_either_member_id_or_mbi        fdos        tdos  \
# 0         NaN                      7GJ5T84QD50  07/25/2022  07/25/2022
# 1         NaN                      6H86JY1DW54  06/05/2023  06/05/2023
# 2         NaN                      6AH0C76FQ17  01/17/2023  01/17/2023
# 3         NaN                      7QY0U85FJ05  01/25/2023  01/25/2023
# 4         NaN                      1DV6GR3MC46  07/20/2022  07/20/2022
#
#    bill_type_institutional_only  nu_indicator_internal_use_  prov_id  \
# 0                           NaN                         NaN      NaN
# 1                           NaN                         NaN      NaN
# 2                           NaN                         NaN      NaN
# 3                           NaN                         NaN      NaN
# 4                           NaN                         NaN      NaN
#
#           npi  prov_type  facility_nm_required_for_institutional  \
# 0  1194221317        NaN                                     NaN
# 1  1720518137        NaN                                     NaN
# 2  1194221317        NaN                                     NaN
# 3  1740410703        NaN                                     NaN
# 4  1740410703        NaN                                     NaN
#
#   prov_last_name_required_for_professional  \
# 0                                   Flippo
# 1                                  Sanchez
# 2                                   Flippo
# 3                                   Bolden
# 4                                   Bolden
#
#   prov_first_name_required_for_professional  \
# 0                                   Jessica
# 1                                    Susana
# 2                                   Jessica
# 3                                     Lacey
# 4                                     Lacey
#
#    cms_specialty_required_for_professional      tax_id  \
# 0                                     50.0  84-2590508
# 1                                     50.0  84-2590508
# 2                                     50.0  84-2590508
# 3                                     50.0  84-2590508
# 4                                     50.0  84-2590508
#
#    cpt_professional_and_hospital_outpatient_only  \
# 0                                          99212
# 1                                          99214
# 2                                          99214
# 3                                          99214
# 4                                          99214
#
#    rev_code_required_for_institutional  service_fdos  service_tdos  \
# 0                                  NaN           NaN           NaN
# 1                                  NaN           NaN           NaN
# 2                                  NaN           NaN           NaN
# 3                                  NaN           NaN           NaN
# 4                                  NaN           NaN           NaN
#
#    pos_professional_only  icd_indic ra_code_required_for_professional  \
# 0                   10.0          0                                 A
# 1                   10.0          0                                 A
# 2                   10.0          0                                 A
# 3                   10.0          0                                 A
# 4                   10.0          0                                 A
#
#    chart_barcode_internal_use_  chart_enc_key_internal_use_  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    chart_dx_key_internal_use_  contract_id_tufts_use_only_  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#        mem_street_address_ mem_address_2     mem_city mem_state  mem_zip_code  \
# 0    601 E BARTON RIDGE RD       Apt 102  GREENEVILLE        TN       37745.0
# 1           584 DELORES DR           NaN    Dandridge        TN       37725.0
# 2       2242 DRY VALLEY RD           NaN   THORN HILL        TN       37881.0
# 3          2114 DUNCAN AVE           NaN  CHATTANOOGA        TN       37404.0
# 4  1201 BOYNTON DR APT 805           NaN  CHATTANOOGA        TN       37402.0
#
#    claimid_pcn     dx_0  dx_1    dx_2    dx_3   dx_4   dx_5   dx_6    dx_7  \
# 0          NaN    G4730  F330    F419   E1151  E1142  E6601  F0390    I509
# 1          NaN     R569   F72   Q8789     I10   E441   H547   Z681    G809
# 2          NaN  S24153S  N319  M62838   G8222    NaN    NaN    NaN     NaN
# 3          NaN     K219  I130   E1142   E6601  N1831   E785  F0390   Z7409
# 4          NaN    F5104   I10   Z7901  G40919   E785   R531  E1169  I69354
#
#     dx_8   dx_9  dx_10 dx_11  dx_12  dx_13   dx_14 dx_15 dx_16 dx_17 dx_18  \
# 0   E261    NaN    NaN   NaN    NaN    NaN     NaN   NaN   NaN   NaN   NaN
# 1   Z931  H9190    NaN   NaN    NaN    NaN     NaN   NaN   NaN   NaN   NaN
# 2    NaN    NaN    NaN   NaN    NaN    NaN     NaN   NaN   NaN   NaN   NaN
# 3  F1120   I509  Z6839  J449  J9611  E1122  I69354   NaN   NaN   NaN   NaN
# 4    NaN    NaN    NaN   NaN    NaN    NaN     NaN   NaN   NaN   NaN   NaN
#
#   dx_19 dx_20 dx_21 dx_22 dx_23 dx_24 dx_25 dx_26 dx_27 dx_28 dx_29 dx_30  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#   dx_31 dx_32 dx_33 dx_34 dx_35 dx_36 dx_37 dx_38 dx_39           err_id  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  483473-10000001
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  483473-10000002
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  483473-10000003
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  483473-10000004
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  483473-10000005
#
#                          error
# 0  err45-Blank or Invalid POS;
# 1  err45-Blank or Invalid POS;
# 2  err45-Blank or Invalid POS;
# 3  err45-Blank or Invalid POS;
# 4  err45-Blank or Invalid POS;

# %%
df.error.value_counts()
# Out:
# err45-Blank or Invalid POS;                                                                                                        13282
# err18-Blank MemberID; err40-Member not found in plan membership; err45-Blank or Invalid POS;                                         379
# err24_ Invalid or Not Risk Adjustable CPT; err45-Blank or Invalid POS;                                                               139
# err45-Blank or Invalid POS; Err66_ContractMismatch(MED);                                                                             130
# err42-Member data mismatch (LN); err45-Blank or Invalid POS;                                                                          44
# err45-Blank or Invalid POS; Err66_ContractMismatch();                                                                                  6
# err22-Blank MBI; err40-Member not found in plan membership; err45-Blank or Invalid POS;                                                4
# err24_ Invalid or Not Risk Adjustable CPT; err42-Member data mismatch (LN); err45-Blank or Invalid POS;                                2
# err42-Member data mismatch (LN); err45-Blank or Invalid POS; Err66_ContractMismatch(MED);                                              2
# err27-Invalid Diag Cd DOS (DX 12); err45-Blank or Invalid POS;                                                                         1
# err27-Invalid Diag Cd DOS (DX 09); err45-Blank or Invalid POS;                                                                         1
# err27-Invalid Diag Cd DOS (DX 05); err45-Blank or Invalid POS;                                                                         1
# err27-Invalid Diag Cd DOS (DX 14); err45-Blank or Invalid POS;                                                                         1
# err18-Blank MemberID; err27-Invalid Diag Cd DOS (DX 02); err40-Member not found in plan membership; err45-Blank or Invalid POS;        1
# err27-Invalid Diag Cd DOS (DX 17); err45-Blank or Invalid POS;                                                                         1
# err27-Invalid Diag Cd DOS (DX 15); err45-Blank or Invalid POS;                                                                         1
# Name: error, dtype: int64

# %%
# HDR|8.9|00795|00795_UHC_ASMP_DIRECT_20220328162146_RESUB1.txt|UHC|DIRECT|P|Y

# %%
df.to_csv('/Users/bp/Downloads/uhc_supp_file_errors_20230615.csv', index=False)

# %%
df.loc[df.error == 'err24_ Invalid or Not Risk Adjustable CPT; err45-Blank or Invalid POS;'].cpt_professional_and_hospital_outpatient_only.value_counts()
# Out:
# 98966    117
# 99211     20
# 99422      1
# 99421      1
# Name: cpt_professional_and_hospital_outpatient_only, dtype: int64

# %%
df.loc[df.error.str.contains('Diag Cd'), ['error', 'fdos'] + df.columns[-42:].tolist()].head(20)
# 'M545' # not valid for billing
# 'I714' # not valid for billing
# 'D7582' # not valid for billing
# 'F03911' # too new `23
# 'Z7985' # too new `23
# Out:
#                                                                                                                                 error  \
# 378                                                                    err27-Invalid Diag Cd DOS (DX 12); err45-Blank or Invalid POS;
# 1367                                                                   err27-Invalid Diag Cd DOS (DX 09); err45-Blank or Invalid POS;
# 3879                                                                   err27-Invalid Diag Cd DOS (DX 05); err45-Blank or Invalid POS;
# 4063                                                                   err27-Invalid Diag Cd DOS (DX 14); err45-Blank or Invalid POS;
# 4988  err18-Blank MemberID; err27-Invalid Diag Cd DOS (DX 02); err40-Member not found in plan membership; err45-Blank or Invalid POS;
# 5227                                                                   err27-Invalid Diag Cd DOS (DX 17); err45-Blank or Invalid POS;
# 5236                                                                   err27-Invalid Diag Cd DOS (DX 15); err45-Blank or Invalid POS;
#
#             fdos    dx_0   dx_1   dx_2    dx_3    dx_4    dx_5   dx_6   dx_7  \
# 378   03/25/2022  Z86718  Z8719   R569    K219   G4700    B182   I739    I10
# 1367  06/29/2022    K219   Z780  G8929  J45909     I10   Z7189  E7800   E039
# 3879  08/24/2022     I10   E785  K7460   F0391  F03911  F17200    NaN    NaN
# 4063  09/16/2022    M109  I4820   K219   E1140   E1151    I495  Z6843  I5032
# 4988  12/02/2022    K219   I714  F0150    I209    B182    I110  I7102   E785
# 5227  01/13/2023  D84821  N1832  E1151    F330   Z6843   E6601  F1320   N052
# 5236  09/19/2022    M109   K219  E1140    K766    D696    F339   Z794  K7469
#
#         dx_8    dx_9  dx_10   dx_11    dx_12   dx_13  dx_14  dx_15  dx_16  \
# 378     R519    E785   F319    M545     J449  F17200  J9611   J302   M069
# 1367    M545   Z9989  I7300   Z1211    Z6827    J302   M069    NaN    NaN
# 3879     NaN     NaN    NaN     NaN      NaN     NaN    NaN    NaN    NaN
# 4063   E6601    I110   E039   D6869     J449   Z7985  J9611  Z9981   E261
# 4988    I509  G40909   I252  I69351      NaN     NaN    NaN    NaN    NaN
# 5227  Z79899  G40909   M159  Z89511  W19XXXA   G4700  E1122  N2581  D7582
# 5236   F4310    E261   R030   Z7722   G40909    J449  Z7985  G4700   F603
#
#        dx_17 dx_18 dx_19 dx_20 dx_21 dx_22 dx_23 dx_24 dx_25 dx_26 dx_27  \
# 378      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1367     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3879     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4063     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4988     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5227  R87810   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5236  E11319   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      dx_28 dx_29 dx_30 dx_31 dx_32 dx_33 dx_34 dx_35 dx_36 dx_37 dx_38 dx_39  \
# 378    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1367   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3879   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4063   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4988   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5227   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5236   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                err_id  \
# 378   483473-10000379
# 1367  483473-10001368
# 3879  483473-10003880
# 4063  483473-10004064
# 4988  483473-10004989
# 5227  483473-10005228
# 5236  483473-10005237
#
#                                                                                                                                 error
# 378                                                                    err27-Invalid Diag Cd DOS (DX 12); err45-Blank or Invalid POS;
# 1367                                                                   err27-Invalid Diag Cd DOS (DX 09); err45-Blank or Invalid POS;
# 3879                                                                   err27-Invalid Diag Cd DOS (DX 05); err45-Blank or Invalid POS;
# 4063                                                                   err27-Invalid Diag Cd DOS (DX 14); err45-Blank or Invalid POS;
# 4988  err18-Blank MemberID; err27-Invalid Diag Cd DOS (DX 02); err40-Member not found in plan membership; err45-Blank or Invalid POS;
# 5227                                                                   err27-Invalid Diag Cd DOS (DX 17); err45-Blank or Invalid POS;
# 5236                                                                   err27-Invalid Diag Cd DOS (DX 15); err45-Blank or Invalid POS;

# %%
df.loc[df.error.str.contains('MemberID')]
# Out:
#       seg_type             ref_    last_name first_name   mi         dob  \
# 139        DTL  432289519042716       Raymer      Daisy  NaN  03/28/1929
# 484        DTL  502836801765532       Friday  Airfearer  NaN  09/04/1954
# 485        DTL  512259942252700       Friday  Airfearer  NaN  09/04/1954
# 486        DTL  581423447670940       Friday  Airfearer  NaN  09/04/1954
# 517        DTL  614794085728412        Mason    Alberta  NaN  08/17/1927
# ...        ...              ...          ...        ...  ...         ...
# 13988      DTL  608853291892892         Bair    Michael  NaN  03/01/1989
# 13989      DTL  608828592095388       Soares        Amy  NaN  12/16/1981
# 13991      DTL  607035621441692       Thomas   Fredrick  NaN  02/27/1969
# 13992      DTL  606311445889180    Panorelli   Victoria  NaN  10/20/1963
# 13993      DTL  611075644063900  Dejoinville       Dawn  NaN  01/30/1973
#
#        member_id_need_either_member_id_or_mbi  retrieval_npi_internal_use_  \
# 139                                       NaN                          NaN
# 484                                       NaN                          NaN
# 485                                       NaN                          NaN
# 486                                       NaN                          NaN
# 517                                       NaN                          NaN
# ...                                       ...                          ...
# 13988                                     NaN                          NaN
# 13989                                     NaN                          NaN
# 13991                                     NaN                          NaN
# 13992                                     NaN                          NaN
# 13993                                     NaN                          NaN
#
#       gender  state_code mbi_need_either_member_id_or_mbi        fdos  \
# 139        F         NaN                      6JY3DN2XN80  03/31/2022
# 484        F         NaN                      1EC3N32FD72  08/19/2022
# 485        F         NaN                      1EC3N32FD72  09/15/2022
# 486        F         NaN                      1EC3N32FD72  03/22/2023
# 517        F         NaN                      1CA2Q38GP29  06/06/2023
# ...      ...         ...                              ...         ...
# 13988      M         NaN                      2XW1JP0EJ93  05/24/2023
# 13989      F         NaN                      3EX5ME7XY75  05/24/2023
# 13991      M         NaN                      3XN2JX7QR82  05/19/2023
# 13992      F         NaN                      5KC9W01TA39  05/18/2023
# 13993      F         NaN                      7GA4FR1EG64  05/29/2023
#
#              tdos  bill_type_institutional_only  nu_indicator_internal_use_  \
# 139    03/31/2022                           NaN                         NaN
# 484    08/19/2022                           NaN                         NaN
# 485    09/15/2022                           NaN                         NaN
# 486    03/22/2023                           NaN                         NaN
# 517    06/06/2023                           NaN                         NaN
# ...           ...                           ...                         ...
# 13988  05/24/2023                           NaN                         NaN
# 13989  05/24/2023                           NaN                         NaN
# 13991  05/19/2023                           NaN                         NaN
# 13992  05/18/2023                           NaN                         NaN
# 13993  05/29/2023                           NaN                         NaN
#
#        prov_id         npi  prov_type  facility_nm_required_for_institutional  \
# 139        NaN  1811345341        NaN                                     NaN
# 484        NaN  1740410703        NaN                                     NaN
# 485        NaN  1740410703        NaN                                     NaN
# 486        NaN  1811345341        NaN                                     NaN
# 517        NaN  1841796091        NaN                                     NaN
# ...        ...         ...        ...                                     ...
# 13988      NaN  1588195986        NaN                                     NaN
# 13989      NaN  1588195986        NaN                                     NaN
# 13991      NaN  1619328531        NaN                                     NaN
# 13992      NaN  1619328531        NaN                                     NaN
# 13993      NaN  1922368877        NaN                                     NaN
#
#       prov_last_name_required_for_professional  \
# 139                                    Freeman
# 484                                     Bolden
# 485                                     Bolden
# 486                                    Freeman
# 517                                    Holland
# ...                                        ...
# 13988                                   Dziama
# 13989                                   Dziama
# 13991                                    Agiri
# 13992                                    Agiri
# 13993                                    Patel
#
#       prov_first_name_required_for_professional  \
# 139                                       Megan
# 484                                       Lacey
# 485                                       Lacey
# 486                                       Megan
# 517                                       Jamie
# ...                                         ...
# 13988                                 Alexandra
# 13989                                 Alexandra
# 13991                                     Kathy
# 13992                                     Kathy
# 13993                                     Megha
#
#        cms_specialty_required_for_professional      tax_id  \
# 139                                       50.0  84-2590508
# 484                                       50.0  84-2590508
# 485                                       50.0  84-2590508
# 486                                       50.0  84-2590508
# 517                                       50.0  84-2590508
# ...                                        ...         ...
# 13988                                     50.0  84-2590508
# 13989                                     50.0  84-2590508
# 13991                                     50.0  84-2590508
# 13992                                     50.0  84-2590508
# 13993                                     50.0  84-2590508
#
#        cpt_professional_and_hospital_outpatient_only  \
# 139                                            99213
# 484                                            99214
# 485                                            99213
# 486                                            99214
# 517                                            99203
# ...                                              ...
# 13988                                          99203
# 13989                                          99203
# 13991                                          99203
# 13992                                          99203
# 13993                                          99203
#
#        rev_code_required_for_institutional  service_fdos  service_tdos  \
# 139                                    NaN           NaN           NaN
# 484                                    NaN           NaN           NaN
# 485                                    NaN           NaN           NaN
# 486                                    NaN           NaN           NaN
# 517                                    NaN           NaN           NaN
# ...                                    ...           ...           ...
# 13988                                  NaN           NaN           NaN
# 13989                                  NaN           NaN           NaN
# 13991                                  NaN           NaN           NaN
# 13992                                  NaN           NaN           NaN
# 13993                                  NaN           NaN           NaN
#
#        pos_professional_only  icd_indic ra_code_required_for_professional  \
# 139                     11.0          0                                 A
# 484                     10.0          0                                 A
# 485                     10.0          0                                 A
# 486                     10.0          0                                 A
# 517                     10.0          0                                 A
# ...                      ...        ...                               ...
# 13988                   10.0          0                                 A
# 13989                   10.0          0                                 A
# 13991                   10.0          0                                 A
# 13992                   10.0          0                                 A
# 13993                   10.0          0                                 A
#
#        chart_barcode_internal_use_  chart_enc_key_internal_use_  \
# 139                            NaN                          NaN
# 484                            NaN                          NaN
# 485                            NaN                          NaN
# 486                            NaN                          NaN
# 517                            NaN                          NaN
# ...                            ...                          ...
# 13988                          NaN                          NaN
# 13989                          NaN                          NaN
# 13991                          NaN                          NaN
# 13992                          NaN                          NaN
# 13993                          NaN                          NaN
#
#        chart_dx_key_internal_use_  contract_id_tufts_use_only_  \
# 139                           NaN                          NaN
# 484                           NaN                          NaN
# 485                           NaN                          NaN
# 486                           NaN                          NaN
# 517                           NaN                          NaN
# ...                           ...                          ...
# 13988                         NaN                          NaN
# 13989                         NaN                          NaN
# 13991                         NaN                          NaN
# 13992                         NaN                          NaN
# 13993                         NaN                          NaN
#
#                 mem_street_address_ mem_address_2         mem_city mem_state  \
# 139             1685 Bunker Hill Rd           NaN       Cookeville        TN
# 484    108 N Auburndale St  Apt 409           NaN          Memphis        TN
# 485    108 N Auburndale St  Apt 409           NaN          Memphis        TN
# 486    108 N Auburndale St  Apt 409           NaN          Memphis        TN
# 517         5185 Highway 57 Apt 24d           NaN        Rossville        TN
# ...                             ...           ...              ...       ...
# 13988                 58b South Ave           NaN        Attleboro        MA
# 13989             350 Bakerville Rd           NaN  South Dartmouth        MA
# 13991               735 Shawmut Ave       Apt 718          Roxbury        MA
# 13992                  240 River St           NaN        Haverhill        MA
# 13993               21b Clarence St           NaN        Attleboro        MA
#
#        mem_zip_code  claimid_pcn   dx_0     dx_1   dx_2    dx_3    dx_4  \
# 139         38506.0          NaN   R627    F0390    NaN     NaN     NaN
# 484         38104.0          NaN   R569  S062X5S  F0390  I69951   N3281
# 485         38104.0          NaN   L089      NaN    NaN     NaN     NaN
# 486         38104.0          NaN   R569  S062X5S  F0390  I69951   N3281
# 517         38066.0          NaN   K219     I152   J449   Z6824   E1159
# ...             ...          ...    ...      ...    ...     ...     ...
# 13988        2703.0          NaN  Z6828     I429  I4891    F339   G1111
# 13989        2748.0          NaN  Z6838      I10  E6601    E785  G43909
# 13991        2119.0          NaN   Z952     E261   I509    Z933    C189
# 13992        1832.0          NaN  E6601     E785   F319    I509   E1169
# 13993        2703.0          NaN   K219   Z90710   F419    F330     I10
#
#         dx_5  dx_6   dx_7    dx_8 dx_9 dx_10 dx_11 dx_12 dx_13 dx_14 dx_15  \
# 139      NaN   NaN    NaN     NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 484      NaN   NaN    NaN     NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 485      NaN   NaN    NaN     NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 486      NaN   NaN    NaN     NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 517      NaN   NaN    NaN     NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...      ...   ...    ...     ...  ...   ...   ...   ...   ...   ...   ...
# 13988   E785  E039  G7100  L98429  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 13989    G35  M069    NaN     NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 13991    B20   NaN    NaN     NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 13992  Z6842  J449    NaN     NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 13993  L4050  E785   D849   R7303  NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#       dx_16 dx_17 dx_18 dx_19 dx_20 dx_21 dx_22 dx_23 dx_24 dx_25 dx_26 dx_27  \
# 139     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 484     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 485     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 486     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 517     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 13988   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 13989   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 13991   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 13992   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 13993   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#       dx_28 dx_29 dx_30 dx_31 dx_32 dx_33 dx_34 dx_35 dx_36 dx_37 dx_38 dx_39  \
# 139     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 484     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 485     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 486     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 517     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 13988   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 13989   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 13991   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 13992   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 13993   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                 err_id  \
# 139    483473-10000140
# 484    483473-10000485
# 485    483473-10000486
# 486    483473-10000487
# 517    483473-10000518
# ...                ...
# 13988  483473-10013989
# 13989  483473-10013990
# 13991  483473-10013992
# 13992  483473-10013993
# 13993  483473-10013994
#
#                                                                                               error
# 139    err18-Blank MemberID; err40-Member not found in plan membership; err45-Blank or Invalid POS;
# 484    err18-Blank MemberID; err40-Member not found in plan membership; err45-Blank or Invalid POS;
# 485    err18-Blank MemberID; err40-Member not found in plan membership; err45-Blank or Invalid POS;
# 486    err18-Blank MemberID; err40-Member not found in plan membership; err45-Blank or Invalid POS;
# 517    err18-Blank MemberID; err40-Member not found in plan membership; err45-Blank or Invalid POS;
# ...                                                                                             ...
# 13988  err18-Blank MemberID; err40-Member not found in plan membership; err45-Blank or Invalid POS;
# 13989  err18-Blank MemberID; err40-Member not found in plan membership; err45-Blank or Invalid POS;
# 13991  err18-Blank MemberID; err40-Member not found in plan membership; err45-Blank or Invalid POS;
# 13992  err18-Blank MemberID; err40-Member not found in plan membership; err45-Blank or Invalid POS;
# 13993  err18-Blank MemberID; err40-Member not found in plan membership; err45-Blank or Invalid POS;
#
# [380 rows x 82 columns]

# %%
conn = cb_utils.get_engine(source="analytics")
df.to_sql("uhc_supp_file_errors_20230615", conn, schema='junk', index=False, method='multi', chunksize=1000)
# Out:
# 13995
